# %%
import numpy as np
import matplotlib.pyplot as plt
import scarplet.scarplet as sl
# Out:
# /home/rmsare/.local/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/rmsare/.local/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from scarplet.WindowedTemplate import Scarp, Channel

# %%
data = sl.load('data/faultzone.tif')
plt.imshow(data._griddata, cmap='terrain')

# %%
# %%time
param = { 'scale' : 100, # window size, m
          'ang_min' : -np.pi / 2, # radians
          'ang_max' : np.pi / 2,
          'kt' : 3
        }

results = sl.match(data, Scarp, **param)
# Out:
# CPU times: user 24.8 s, sys: 6.68 s, total: 31.4 s
# Wall time: 2min 31s

# %%
sl.plot_results(data, results, figsize=(8, 32))
